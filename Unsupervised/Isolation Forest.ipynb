# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.ensemble import IsolationForest

# %%
data = pd.read_csv('AnomalyDetection.csv')

# %%
data
# Out:
#        Mileage       Price
# 0    54.282388   67.967708
# 1    17.331911   70.023637
# 2    36.548113   68.080455
# 3    42.567541   71.058755
# 4     5.608853   57.822432
# ..         ...         ...
# 903   5.584939  117.000000
# 904  70.000000   20.000000
# 905  68.000000   22.000000
# 906  70.000000   60.000000
# 907  71.000000   78.000000
#
# [908 rows x 2 columns]

# %%
clf = IsolationForest(n_estimators=1000,contamination=0.1).fit_predict(data)

# %%
plt.scatter(x=data['Mileage'],y=data['Price'],c=clf)

# %%
from sklearn.neighbors import LocalOutlierFactor

# %%
clf  = LocalOutlierFactor(n_neighbors=25,contamination=0.1).fit_predict(data)

# %%
plt.scatter(x=data['Mileage'],y=data['Price'],c=clf)
