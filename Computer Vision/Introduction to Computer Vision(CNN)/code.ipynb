# %% [markdown]
# # Colab links

# %% [markdown]
# lec1 - https://colab.research.google.com/drive/19EceYgXDaZiiX3-GsdmnzWcwtWjN8zSK?usp=sharing

# %% [markdown]
# ## When there's no edge

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## When there's an actual Edge

# %% [markdown]
# ![image.png](attachment:image.png)
