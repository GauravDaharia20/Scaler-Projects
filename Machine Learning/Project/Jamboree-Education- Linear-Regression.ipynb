# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data  = pd.read_csv('data.csv')

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
data.drop('Serial No.',axis=1,inplace=True)

# %% [markdown]
# # Missing Value check

# %%
data.isna().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
data.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000         500.00000
# mean     8.576440    0.560000           0.72174
# std      0.604813    0.496884           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# ...

# %%
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
def get_histplot(data,title,bins=20):
    plt.title(title)
    plt.grid()
    sns.histplot(data,bins=bins)
    mean = np.mean(data)
    std = np.std(data)
    print(f'mean : {mean} , std : {std}')
    plt.show()
def get_kde_plot(data,title):
    plt.title(title)
    plt.grid()
    sns.kdeplot(data)
    mean = np.mean(data)
    std = np.std(data)
    print(f'mean : {mean} , std : {std}')
    plt.show()
    
    
def get_box_plot(data,title):
    plt.title(title)
    sns.boxplot(data)
    plt.show()

# %%
gre_score  = data['GRE Score']

# %%
get_kde_plot(gre_score,'GRE_SCORE')

"""
data dip in between 310 to 320
"""
# Out:
# mean : 316.472 , std : 11.28384757075351
# '\ndata dip in between 310 to 320\n'

# %% [markdown]
# # Outlier check for GRE score

# %%
get_box_plot(gre_score,'GRE_SCORE')

# %%
toefl_score  = data['TOEFL Score']
get_kde_plot(toefl_score,'TOEFL_SCORE')

"""
data dip in between 105 to 110 in score

"""
# Out:
# mean : 107.192 , std : 6.075782747926387
# '\ndata dip in between 105 to 110 in score\n\n'

# %% [markdown]
# # Outlier check for TOEFL Score

# %%
get_box_plot(toefl_score,'TOEFL_SCORE')

# %%
University_Rating  = data['University Rating']
get_histplot(University_Rating,'University_Rating')
# Out:
# mean : 3.114 , std : 1.1423677166306818

# %%
SOP  = data['SOP']
get_kde_plot(SOP,'SOP')
# Out:
# mean : 3.374 , std : 0.9900121211379178

# %% [markdown]
# # Outlier check for SOP Score

# %%
get_box_plot(SOP,'SOP')

# %%
data.columns = [i.strip() for i in data.columns]

# %%
LOR  = data['LOR']
get_kde_plot(LOR,'LOR')
"""
dip in 3 to 4 range.
"""
# Out:
# mean : 3.484 , std : 0.9245236611358293
# '\ndip in 3 to 4 range.\n'

# %% [markdown]
# # Outlier check for LOR Score

# %%
get_box_plot(LOR,'LOR')

# %%
CGPA  = data['CGPA']
get_kde_plot(CGPA,'CGPA')
# Out:
# mean : 8.576439999999998 , std : 0.6042076848236868

# %% [markdown]
# # Outlier check for CGPA Score

# %%
get_box_plot(CGPA,'CGPA')

# %%
Research  = data['Research']
get_histplot(Research,'Research')
# Out:
# mean : 0.56 , std : 0.49638694583963355

# %%
plt.figure(figsize=(10,20))
sns.pairplot(data, y_vars=["Chance of Admit"]);
plt.show()

# %%
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %%
plt.title('GRE_SCORE VS Chance of Admit')
sns.scatterplot(data=data ,x='GRE Score',y='Chance of Admit',hue='Research')
plt.grid()
plt.xlabel('GRE_SCORE')
plt.ylabel('Chance of Admit')
plt.show()

# %%
count_research = len(data.loc[data['Research']==1])
count_research_gre_gt_320 = len(data.loc[data['Research']==1 & (data['GRE Score']>=320)])
count_research_gre_lt_320 = len(data.loc[data['Research']==1 & (data['GRE Score']<=320)])

count_non_research_gre_gt_320 = len(data.loc[data['Research']==0 & (data['GRE Score']>=320)])
count_non_research_gre_lt_320  = len(data.loc[data['Research']==0 & (data['GRE Score']<=320)])


print(f'researcher count having gre_score > 320 -> {count_research_gre_gt_320} , researcher count having gre_score < 320 -> {count_research_gre_lt_320}')
print(f'non researcher count having gre_score > 320 -> {count_non_research_gre_gt_320} , non researcher count having gre_score < 320 -> {count_non_research_gre_lt_320}')

count_no_research = len(data.loc[data['Research']==0])
print(f'researcher count : {count_research} , no_researcher_count : {count_no_research}')
# Out:
# researcher count having gre_score > 320 -> 387 , researcher count having gre_score < 320 -> 121
# non researcher count having gre_score > 320 -> 220 , non researcher count having gre_score < 320 -> 220
# researcher count : 280 , no_researcher_count : 220

# %% [markdown]
# # Data Insights
#
# 1. Students with no research background and having gre_Score > 320 have high probability of getting admission.
#
# 2. Students with research background and having gre_Score > 320 have high probability of getting admission.
#
# 3. Students with no research background have probability of admission in range of 0.4 to 0.8.
#
# 4. Students with research background have probability of admission in range of 0.7 to 1.0 .

# %%
plt.title('TOEFL_Score VS Chance of Admit')
sns.scatterplot(data = data,x='TOEFL Score',y='Chance of Admit',hue='Research')
plt.grid()
plt.xlabel('TOEFL_Score')
plt.ylabel('Chance of Admit')
plt.show()

# %%
count_research_toefl_gt_105 = len(data.loc[data['Research']==1 & (data['TOEFL Score']>=105)])
count_research_lt_toefl_105 = len(data.loc[data['Research']==1 & (data['GRE Score']<=105)])

count_non_research_toefl_gt_105 = len(data.loc[data['Research']==0 & (data['GRE Score']>=105)])
count_non_research_toefl_lt_105  = len(data.loc[data['Research']==0 & (data['GRE Score']<=105)])


print(f'researcher count having toefl score > 105 -> {count_research_toefl_gt_105} , researcher count having toefl score < 105 -> {count_research_lt_toefl_105}')
print(f'non researcher count having toefl score > 105 -> {count_non_research_toefl_gt_105} , non researcher count having toefl score < 105 -> {count_non_research_toefl_lt_105}')
# Out:
# researcher count having toefl score > 105 -> 344 , researcher count having toefl score < 105 -> 220
# non researcher count having toefl score > 105 -> 220 , non researcher count having toefl score < 105 -> 220

# %% [markdown]
# # Data insights
#
# 1. Students with research background having toefl score > 105 have admission probability in range of 0.7 to 1.0 .
#
# 2. Students with research background having toefl score < 105 have admission probability in range of 0.45 to 0.75 .
#
# 3. Students with non-research background having toefl score < 105 have admission probability in range of 0.3 to 0.75 .
#
# 4. Students with non-research background having toefl score > 105 have admission probability in range of 0.45 to 0.9 .

# %%
plt.title('University Rating Vs Chance of Admit')
sns.barplot(data=data,x='University Rating',y='Chance of Admit')
plt.show()

# %%
plt.title('SOP VS Chance of Admit')
sns.scatterplot(data=data ,x='SOP',y='Chance of Admit',hue='Research')
plt.grid()
plt.xlabel('SOP')
plt.ylabel('Chance of Admit')
plt.show()

# %% [markdown]
# # Data Insights
#
# 1. Students having SOP rating in range of 4 to 5 are belonging to research background.
#
# 2. Students having SOP rating in range of 1 to 4 are belonging to non-research background.

# %%
plt.title('LOR VS Chance of Admit')
sns.scatterplot(data=data ,x='LOR',y='Chance of Admit',hue='Research')
plt.grid()
plt.xlabel('LOR')
plt.ylabel('Chance of Admit')
plt.show()

# %% [markdown]
# # Data Insights
#
# 1. Students having LOR rating in range of 3 to 5 are belonging to research background.
#
# 2. Students having SOP rating in range of 1 to 2.5 are belonging to non-research background.

# %%
plt.title('CGPA VS Chance of Admit')
sns.scatterplot(data=data ,x='CGPA',y='Chance of Admit',hue='Research')
plt.grid()
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit')
plt.show()

# %% [markdown]
# # Data Insights
#
# 1. Students having CGPA in range of 8.5 to 10 are have high chances of getting admission
#
# 2. Students having CGPA in range of 7.0 to 8.5 are belonging to non-research background.

# %%
plt.figure(figsize=(20,5))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %% [markdown]
# # VIF Check

# %%
from sklearn.model_selection import train_test_split as tts
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Standardizing data

# %%
def check_vif(df):
    tmp = df.columns
    df = StandardScaler().fit_transform(df)
    df = pd.DataFrame(df,columns=tmp)
    vif_df = pd.DataFrame()
    vif_df['Features'] = df.columns
    vif_df["VIF"] = [round(variance_inflation_factor(df.values, i),2) for i in range(len(df.columns))]
    return vif_df,df

# %%
vif,data = check_vif(data)

# %%
vif
# Out:
#             Features   VIF
# 0          GRE Score  4.59
# 1        TOEFL Score  3.98
# 2  University Rating  2.63
# 3                SOP  2.84
# 4                LOR  2.10
# 5               CGPA  6.22
# 6           Research  1.54
# 7    Chance of Admit  5.61

# %% [markdown]
# # Observation on VIF Score
# Only feature we have Varience inflation factor greater than 5,so we have to drop CGPA from it.

# %%
data.drop('CGPA',axis=1,inplace=True)

# %%
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating       SOP       LOR  Research  \
# 0   1.819238     1.778865           0.775582  1.137360  1.098944  0.886405
# 1   0.667148    -0.031601           0.775582  0.632315  1.098944  0.886405
# 2  -0.041830    -0.525364          -0.099793 -0.377773  0.017306  0.886405
# 3   0.489904     0.462163          -0.099793  0.127271 -1.064332  0.886405
# 4  -0.219074    -0.689952          -0.975168 -1.387862 -0.523513 -1.128152
#
#    Chance of Admit
# 0         1.406107
# 1         0.271349
# 2        -0.012340
# 3         0.555039
# 4        -0.508797

# %% [markdown]
# # Again calculating VIF of remaining features

# %%
vif,data = check_vif(data)

# %%
vif
# Out:
#             Features   VIF
# 0          GRE Score  4.27
# 1        TOEFL Score  3.86
# 2  University Rating  2.61
# 3                SOP  2.77
# 4                LOR  2.08
# 5           Research  1.53
# 6    Chance of Admit  4.31

# %%
data
# Out:
#      GRE Score  TOEFL Score  University Rating       SOP       LOR  Research  \
# 0     1.819238     1.778865           0.775582  1.137360  1.098944  0.886405
# 1     0.667148    -0.031601           0.775582  0.632315  1.098944  0.886405
# 2    -0.041830    -0.525364          -0.099793 -0.377773  0.017306  0.886405
# 3     0.489904     0.462163          -0.099793  0.127271 -1.064332  0.886405
# 4    -0.219074    -0.689952          -0.975168 -1.387862 -0.523513 -1.128152
# ..         ...          ...                ...       ...       ...       ...
# 495   1.376126     0.132987           1.650957  1.137360  0.558125  0.886405
# 496   1.819238     1.614278           1.650957  1.642404  1.639763  0.886405
# 497   1.198882     2.108041           1.650957  1.137360  1.639763  0.886405
# 498  -0.396319    -0.689952           0.775582  0.632315  1.639763 -1.128152
# 499   0.933015     0.955926           0.775582  1.137360  1.098944 -1.128152
#
#      Chance of Admit
# 0           1.406107
# ...

# %%
import statsmodels.api as sm
X = data.loc[:,'GRE Score':'Research']
Y = data['Chance of Admit']
X = sm.add_constant(X)
X
# Out:
#      const  GRE Score  TOEFL Score  University Rating       SOP       LOR  \
# 0      1.0   1.819238     1.778865           0.775582  1.137360  1.098944
# 1      1.0   0.667148    -0.031601           0.775582  0.632315  1.098944
# 2      1.0  -0.041830    -0.525364          -0.099793 -0.377773  0.017306
# 3      1.0   0.489904     0.462163          -0.099793  0.127271 -1.064332
# 4      1.0  -0.219074    -0.689952          -0.975168 -1.387862 -0.523513
# ..     ...        ...          ...                ...       ...       ...
# 495    1.0   1.376126     0.132987           1.650957  1.137360  0.558125
# 496    1.0   1.819238     1.614278           1.650957  1.642404  1.639763
# 497    1.0   1.198882     2.108041           1.650957  1.137360  1.639763
# 498    1.0  -0.396319    -0.689952           0.775582  0.632315  1.639763
# 499    1.0   0.933015     0.955926           0.775582  1.137360  1.098944
#
#      Research
# 0    0.886405
# 1    0.886405
# 2    0.886405
# 3    0.886405
# ...

# %% [markdown]
# # Spliting data into training and testing

# %%
xtrain,xtest,ytrain,ytest = tts(X,Y,test_size=0.25,random_state=0)

# %% [markdown]
# # Finding Optimum weights using Gradient Descent

# %%
def hypothesis(x,weights):
    y_hat = np.dot(x,weights)
    return y_hat

def error(X,Y,weights):
    e=0.0
    m = X.shape[0]
    y_hat = hypothesis(X,weights)
    e = np.sum((Y-y_hat)**2)
    return e/m

def gradient(X,Y,weights):
    y_hat = hypothesis(X,weights)
    grad = np.dot(X.T,(y_hat-Y))
    m = X.shape[0]
    
    return grad/m

def gradient_descent(X,Y,lr=0.1,epoches=1000):
    m = X.shape[1]
    weights = np.zeros((m,))
    error_list = []
    
    for i in range(epoches):
        e = error(X,Y,weights)
        error_list.append(e)
        
        grad = gradient(X,Y,weights)
        
        weights = weights - lr * grad
    return weights,error_list 



def adj_r2_score(r2_score,xtest,ytest):
    num = (1-r2_score)*(len(ytest)-1)
    denom = len(ytest)-xtest.shape[1]-1
    adjr2_sq = 1-(num/denom)
    return adjr2_sq

# %%
weights,error_list = gradient_descent(xtrain,ytrain,lr=0.01)

# %%
plt.title('error list for training data')
plt.plot(error_list)
plt.xlabel('Epoches')
plt.ylabel('Error')
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
y_pred_gd = hypothesis(xtest,weights)

# %%
print(f' r2_score : {r2_score(ytest,y_pred_gd)}')
print(f' adj_r2_score : {adj_r2_score(r2_score(ytest,y_pred_gd),xtest,ytest)}')
# Out:
#  r2_score : 0.7321025000510855
#  adj_r2_score : 0.7160744444985863

# %%
fig = plt.figure()
plt.title('GRE SCORE test data  VS Prediction data')
plt.scatter(xtest['GRE Score'],ytest,label='data')
plt.scatter(xtest['GRE Score'],y_pred_gd,color='orange',label='prediction')
plt.legend()
plt.show()

# %% [markdown]
# # Assumptions test of linear regression
# # Assumption 1: Residuals are independent of each other.
# # Assumption 2: Residuals should have a constant variance.

# %%
residual_gd = ytest-y_pred_gd
sns.residplot(x=y_pred_gd,y=residual_gd,color='darkorange')
plt.xlabel("y_predict")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %% [markdown]
# From the above residual plot, we could infer that the residuals didn’t form any pattern. So, the residuals are independent of each other.
#
# And also, the residuals have constant variance. Variance doesn’t seem to increase/decrease constantly with the y_predict value.

# %% [markdown]
# # Assumption 3: Residuals are normally distributed
# To check whether the residuals are normally distributed from Q-Q plot,distplot
#
# Q-Q plot → quantile-quantile plot
# If the residuals are normally distributed, then the Q-Q plot of residuals will be a straight line

# %%
from scipy import stats
probplot=sm.ProbPlot(residual_gd,stats.norm,fit=True)
fig=probplot.qqplot(line='45')
plt.title('qqplot')
plt.show()

# %%
plt.title('Normality check of residuals')
sns.distplot(residual_gd,color='darkorange')
plt.show()
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_16408\2366671046.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residual_gd,color='darkorange')

# %% [markdown]
# # Mean of Residuals

# %%
mean_of_residual_gd = np.mean(residual_gd)
print(f'mean_of_residual :{mean_of_residual_gd}')
# Out:
# mean_of_residual :0.004759225283660012

# %% [markdown]
# # Test for Hetroskedasticity

# %%
sns.residplot(x=ytest,y=residual_gd,color='darkorange')
plt.grid()
plt.ylabel('residual')
plt.show()

# %% [markdown]
# Above figure shows that there is no sign of hetroskedasity because most of the varience are in range of -0.5 to 0.5

# %% [markdown]
# # Training linear regression model using statsmodel

# %%
model_sm = sm.OLS(ytrain, xtrain).fit()

# %%
print(f'adjusted r2_Score : {model_sm.rsquared_adj}')
print(f'r2_Score : {model_sm.rsquared}')
# Out:
# adjusted r2_Score : 0.7740871252650813
# r2_Score : 0.7777113959827537

# %%
y_pred_sm = model_sm.predict(xtest)

# %%
fig = plt.figure()
plt.scatter(xtest['GRE Score'],ytest,label='data')
plt.scatter(xtest['GRE Score'],y_pred_sm,color='orange',label='prediction')
plt.legend()
plt.show()

# %% [markdown]
# # Assumptions test of linear regression
# # Assumption 1: Residuals are independent of each other.
# # Assumption 2: Residuals should have a constant variance.

# %%
residual_stats_model = ytest-y_pred_sm
sns.residplot(x=y_pred_sm,y=residual_stats_model,color='darkorange')
plt.xlabel("y_predict")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %% [markdown]
# From the above residual plot, we could infer that the residuals didn’t form any pattern. So, the residuals are independent of each other.
#
# And also, the residuals have constant variance. Variance doesn’t seem to increase/decrease constantly with the y_predict value.

# %% [markdown]
# # Assumption 3: Residuals are normally distributed
# To check whether the residuals are normally distributed from Q-Q plot,distplot
#
# Q-Q plot → quantile-quantile plot
# If the residuals are normally distributed, then the Q-Q plot of residuals will be a straight line

# %%
probplot=sm.ProbPlot(residual_stats_model,stats.norm,fit=True)
fig=probplot.qqplot(line='45')
plt.title('qqplot')
plt.show()

# %%
plt.title('Normality check of residuals')
sns.distplot(residual_stats_model,color='darkorange')
plt.show()
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_16408\3002355504.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residual_stats_model,color='darkorange')

# %% [markdown]
# # Mean of Residuals

# %%
mean_of_residual_sm = np.mean(residual_stats_model)
print(f'mean_of_residual :{mean_of_residual_sm}')
# Out:
# mean_of_residual :0.004515713914597054

# %% [markdown]
# # Test for Hetroskedasticity

# %%
sns.residplot(x=ytest,y=residual_stats_model,color='darkorange')
plt.grid()
plt.ylabel('residual')
plt.show()

# %% [markdown]
# Above figure shows that there is no sign of homoscedasity because most of the varience are in range of -0.5 to 0.5

# %% [markdown]
# # Training model using Scikit learn linear Regression algorithm

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred_linear_model = model.predict(xtest)

# %%
print(f'r2_score of train data : {model.score(xtrain,ytrain)}')

print(f'r2_score of test data : {model.score(xtest,ytest)}')

print(f'adj_r2_score : {adj_r2_score(r2_score(ytest,ypred_linear_model),xtest,ytest)}')
# Out:
# r2_score of train data : 0.7777113959827536
# r2_score of test data : 0.7304425298547268
# adj_r2_score : 0.7143151598460352

# %% [markdown]
# # Assumptions test of linear regression
# # Assumption 1: Residuals are independent of each other.
# # Assumption 2: Residuals should have a constant variance.

# %%
residual_lr_model = ytest-ypred_linear_model
sns.residplot(x=ypred_linear_model,y=residual_lr_model,color='darkorange')
plt.xlabel("y_predict")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %% [markdown]
# From the above residual plot, we could infer that the residuals didn’t form any pattern. So, the residuals are independent of each other.
#
# And also, the residuals have constant variance. Variance doesn’t seem to increase/decrease constantly with the y_predict value.

# %% [markdown]
# # Assumption 3: Residuals are normally distributed
# To check whether the residuals are normally distributed from Q-Q plot,distplot
#
# Q-Q plot → quantile-quantile plot
# If the residuals are normally distributed, then the Q-Q plot of residuals will be a straight line

# %%
probplot=sm.ProbPlot(residual_lr_model,stats.norm,fit=True)
fig=probplot.qqplot(line='45')
plt.title('qqplot')
plt.show()

# %%
plt.title('Normality check of residuals')
sns.distplot(residual_lr_model,color='darkorange')
plt.show()
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_16408\802431448.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residual_lr_model,color='darkorange')

# %% [markdown]
# # Mean of Residuals

# %%
mean_of_residual = np.mean(residual_lr_model)
print(f'mean_of_residual :{mean_of_residual}')
# Out:
# mean_of_residual :0.004515713914596857

# %% [markdown]
# # Test for Hetroskedasticity

# %%
sns.residplot(x=ytest,y=residual_lr_model,color='darkorange')
plt.grid()
plt.ylabel('residual')
plt.show()

# %%
Final_result = pd.DataFrame()

# %%
Final_result['models']=['Gradient Decent','Linear_Regression_sm','Linear_Regression_scikit_learn']
Final_result['r2_score']=[r2_score(ytest,y_pred_gd),model_sm.rsquared,model.score(xtest,ytest)]
Final_result['r2_score_adj']=[adj_r2_score(r2_score(ytest,y_pred_gd),xtest,ytest),model_sm.rsquared_adj,adj_r2_score(r2_score(ytest,ypred_linear_model),xtest,ytest)]

# %%
Final_result
# Out:
#                            models  r2_score  r2_score_adj
# 0                 Gradient Decent  0.732103      0.716074
# 1            Linear_Regression_sm  0.777711      0.774087
# 2  Linear_Regression_scikit_learn  0.730443      0.714315

# %% [markdown]
# # Recommendation
#
# 1. Prediction accuracy can be improved if added more features like location, university rankings etc.
# 2. As per analysis on model have potential to perform good prediction in real time data.
# 3. Through this model end user as well as business can be benefitted since it is able to predict the chance with 77% accuracy.
# 4. Accuracy can be increased if more data points are provided.
