# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cars24-car-price-clean.csv')

# %%
df
# Out:
#        selling_price      year  km_driven   mileage    engine  max_power  \
# 0          -1.111046 -0.801317   1.195828  0.045745 -1.310754  -1.157780
# 1          -0.223944  0.450030  -0.737872 -0.140402 -0.537456  -0.360203
# 2          -0.915058 -1.426990   0.035608 -0.582501 -0.537456  -0.404885
# 3          -0.892365 -0.801317  -0.409143  0.329620 -0.921213  -0.693085
# 4          -0.182683  0.137194  -0.544502  0.760085  0.042999   0.010435
# ...              ...       ...        ...       ...       ...        ...
# 19815      -0.017641  0.762867   0.218923  0.950886 -0.215410  -0.694202
# 19816       0.549692  1.388540  -0.776546 -0.466159 -0.198054  -0.156899
# 19817      -0.481822  0.137194   0.170967  0.380810  0.042999   0.120577
# 19818       1.168601  0.450030  72.355997 -0.815185  1.356256   0.935579
# 19819       1.117025  1.388540  -0.873231 -0.349818  0.041071   0.435139
#
#             age      make     model  Individual  Trustmark Dealer    Diesel  \
# ...

# %%
X = df['model'].values
Y = df['selling_price'].values

# %%
def predict(x,weights):
    y_hat = weights[1]*x + weights[0]
    return y_hat

def error(x,y,weights):
    n = x.shape[0]
    total_err = 0
    for i in range(n):
        y_pred = predict(x[i],weights)
        err = (y[i]-y_pred)**2
        total_err += err
    return total_err/n

def gradient(x,y,weights):
    n = x.shape[0]
    
    grads = np.zeros((2,))
    
    for i in range(n):
        
        y_hat = predict(x[i],weights)
        Y = y[i]
        grads[0]+=(-2*(Y-y_hat))
        grads[1]+=(-2*(Y-y_hat)*x[i])
        
    return grads/n
        
def gradient_decent(x,y,epochs=20,lr=0.1):
    weights = np.zeros((2,))
    total_error=[]
    weight_list=[]
    for i in range(epochs):
        grad = gradient(x,y,weights)
        
        errors = error(x,y,weights)
        total_error.append(errors)
        weights[0]-= lr*grad[0]
        weights[1]-= lr*grad[1]
        
        weight_list.append((weights[0],weights[1]))
    
    return weights,weight_list,total_error

# %%
weights,weight_list,total_error = gradient_decent(X,Y)

# %%
plt.plot(list(range(20)),total_error)
plt.xlabel('epochs')
plt.ylabel('errors')
# Out:
# Text(0, 0.5, 'errors')

# %%
plt.plot(np.array(weight_list)[:,0],label='weight0')
plt.legend()
# plt.xlabel('epochs')
# plt.ylabel('weight0')

# %%
plt.plot(np.array(weight_list)[:,1],label='weight1')

# %%
fig = plt.figure()
Y_hat = predict(X,weights)
plt.scatter(X,Y)
plt.plot(X,Y_hat,color='orange',label="Prediction")
plt.legend()
plt.show()
