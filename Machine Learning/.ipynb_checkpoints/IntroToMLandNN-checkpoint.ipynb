# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('spiral.csv')

# %%
plt.title('Data Diagram')
plt.scatter(x=df['x1'],y=df['x2'],c=df['y'])
plt.show()

# %%
X = df
X = X.drop('y',axis=1)
Y = df['y']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report

# %%
clf = LogisticRegression(random_state=0).fit(X,Y)

# %%
y_pred = clf.predict(X)

# %%
print(classification_report(Y,y_pred,target_names=['c1','c2','c3']))
# Out:
#               precision    recall  f1-score   support
#
#           c1       0.52      0.50      0.51       100
#           c2       0.57      0.56      0.56       100
#           c3       0.48      0.50      0.49       100
#
#     accuracy                           0.52       300
#    macro avg       0.52      0.52      0.52       300
# weighted avg       0.52      0.52      0.52       300
