# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 6)

# %% [markdown]
# ## data  link https://docs.google.com/spreadsheets/d/19ngXozNKjFpCcmZVtHZKkzoCMB4AxXvF/edit?usp=drive_link&ouid=113589365975036813444&rtpof=true&sd=true

# %%
mobile_sales = pd.read_excel('mobilesales.xlsx')
mobile_sales.head()
# Out:
#         DATE   Sales
# 0 2001-01-01  6519.0
# 1 2001-02-01  6654.0
# 2 2001-03-01  7332.0
# 3 2001-04-01  7332.0
# 4 2001-05-01  8240.0

# %%
mobile_sales.DATE.describe()
# Out:
# <ipython-input-4-43749c50e8e9>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   mobile_sales.DATE.describe()
# count                     217
# unique                    217
# top       2009-08-01 00:00:00
# freq                        1
# first     2001-01-01 00:00:00
# last      2019-01-01 00:00:00
# Name: DATE, dtype: object

# %%
18*12+1
# Out:
# 217

# %%
# Always make the date/time column as index 
mobile_sales.set_index('DATE', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-cc7c62cc7dd2> in <module>
#       1 # Always make the date/time column as index
# ----> 2 mobile_sales.set_index('DATE', inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['DATE'] are in the columns"

# %%
plt.rcParams['figure.figsize'] = (20, 6)

# %%
#plt.figure(figsize=(20,10))
mobile_sales.plot(label = 'mobilesales',figsize =(20,10), style = 'o-' )
plt.legend()
#plt.show(style = 'o-')

# %%
mn = mobile_sales.Sales.mean()

# %%
mobile_sales.Sales.fillna(mn).plot(label='imputed')
mobile_sales.Sales.plot(label='original')
plt.legend()

# %%
mobile_sales.Sales.interpolate(method='linear').plot(label='imputed')
mobile_sales.Sales.plot(label='original')
plt.legend()

# %%
mobile_sales.Sales.hist(bins=100).plot()
# Out:
# []

# %%
mobile_sales.Sales = mobile_sales.Sales.clip(upper=mobile_sales.Sales.quantile(0.99), lower=mobile_sales.Sales.quantile(0.01))

# %%
mobile_sales.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
mobile_sales = pd.read_excel('mobilesales.xlsx')
mobile_sales.set_index('DATE', inplace=True)
mobile_sales.Sales = mobile_sales.Sales.interpolate()
mobile_sales.Sales = mobile_sales.Sales.clip(upper=mobile_sales.Sales.quantile(0.99), lower=mobile_sales.Sales.quantile(0.01))
mobile_sales.Sales.plot(style='-o')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
mobile_sales.Sales.plot(style='-o')
mobile_sales.Sales.rolling(12, center=False).mean().plot()
mobile_sales.Sales.rolling(12, center=True).mean().plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
import statsmodels.api as sm

model = sm.tsa.seasonal_decompose(mobile_sales.Sales, model='additive')

# %%
model.plot()

# %%
model = sm.tsa.seasonal_decompose(mobile_sales.Sales, model='multiplicative')

# %%
model.plot()
